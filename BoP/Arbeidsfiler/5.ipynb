# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace (0, 2*np.pi, 6)
y = np.sin(x)
z = np.cos(x)
plt.plot (z, y)
plt.show()

# %%
x = np.linspace (0, 2*np.pi, 30)
y = np.sin(x)
z = np.cos(x)
plt.plot (z, y)
plt.show()
