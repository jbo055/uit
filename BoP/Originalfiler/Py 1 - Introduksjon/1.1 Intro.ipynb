# %% [markdown]
# # <font color=blue> Beregningsorienert programmering med Python
# ![0-0%20Introduksjon%20BoPoS%20v19%20b1.png](attachment:0-0%20Introduksjon%20BoPoS%20v19%20b1.png)
# ### 5 studiepoeng <br> Felles fag for alle på Bachelor ingeniør

# %% [markdown]
# ## Bakgrunn
# - Dere skal lære programmering som kan anvendes i fag og yrke
# - En del av ingeniørens verktøykasse
#     - Rask økenede popularitet som beregnigsverktøy
# - Forventer å bruke dataverktøy
#     - Er til dels vant til det fra videregående
# - Forventes at dere behersker grunnleggende programmeringsteknikker

# %% [markdown]
# ## Valg av Python som plattform for BoP
# - Kraftig
# - Fleksibelt
# - Lav begynnerterskel
# - Gratis
# - Kan kjøres uten kompilerig
# - Fått stor utbredelse
# - Har mange tillegsmoduler

# %% [markdown]
# ## <font color=orange> Her er det som dere trenger å installere på egen maskin:
# > <br>
# > <br>
# > <br>
# > <br>
#
# Altså ingen ting
