# %% [markdown]
# ## Likninger og polynomer

# %% [markdown]
# I denne seksjonen skal vi se på hvordan vi kan løse lineære likningsett med flere ukjente og polynomer med Python

# %% [markdown]
# - Lineære likningssett
#     - Metode
#     - Eksempler
#         - 2 ukjente
#         - 3 ukjente
#     - Uten entydig løsning
# - Polynomer
#     - Røtter
#     - Evaluering
#     - Delbrøker
#     - Derivasjon/Integrasjon
#
# ![Lineære likningssett.png](attachment:5cee6149-9b4f-4746-941b-43b04caa357e.png)
