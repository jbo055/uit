# %% [markdown]
# ## Sammensatte betingelser

# %% [markdown]
# Betingelser kan bli ganske komplekse.
# Eksempel:
# ```Python
# a=4 b=6 c=9
# ((a<b and c>b) or not(c>a))
# ```

# %% [markdown]
# #### Sammensatte betingelser og presedens

# %% [markdown]
# For å kunne sette opp og evaluere slike uttrykk må vi også vite presedens på operatorene.

# %% [markdown]
# ![Operatorpresedens.png](attachment:ab3ddccb-d746-4d5b-bf0f-39112ec7ab60.png)

# %% [markdown]
# + Høyest presedens øverst i tabellen
#     + Har fått med de logiske operatorene i tillegg til de aritmetiske
#     + **//** og **%** (Heltallsdivisjon og rest) er på samme linje som multiplikasjon og divisjon
#
# Eksempel:

# %%
alder = int(input('Din alder?: ') )

if (alder >= 13) and (alder <= 19):
    print('Du er tenåring')
else:
    print('Du er ikke tenåring')
# Out:
# Din alder?:  22
# Du er ikke tenåring

# %% [markdown]
# Legg merke til hvordan man tester om en variabel ligger mellom to verdier
# + To adskilte betingelser som begge må være oppfylt

# %% [markdown]
# #### Velge betingelser

# %% [markdown]
# Må noen ganger sette sammen flere typer tester
# + Må holde orden på
#     + betingelsene
#     + resultatene
# + Ikke alltid lurt å bruke sammensatte betingelser
#     + Unngå at man gjør unødvendige tester
# + Kan bruke elif
#     + bare med likeverdige betingelser
#
# Eksempel: Finne størst og minst blant tre verdier

# %%
a = int(input('Skriv inn tall a:') )
b = int(input('Skriv inn tall b:') )
c = int(input('Skriv inn tall c:') )

if a < b:
    if c <= a:
        print('c er minst, b er størst')
    elif c < b:
        disp('a er minst, b er størst')
    else:
        print('a er minst, c er størst')
else:    # Betingelsene er ikke likeverdige
    if c <= b:   # Kan ikke bruke elseif
        print('c er minst, a er størst')
    elif a < c:
        print('b er minst, c er størst')
    else:
        print('b er minst, a er størst')
# Out:
# Skriv inn tall a: 7
# Skriv inn tall b: 9
# Skriv inn tall c: 3
# c er minst, b er størst
