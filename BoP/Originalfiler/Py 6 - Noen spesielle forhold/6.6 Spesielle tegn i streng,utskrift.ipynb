# %% [markdown]
# ## Spesielle tegn i streng, utskrift

# %% [markdown]
# Det er noen tegn som er ulovlig å ha i en streng.
#
# Når vi lager en streng kan vi omslutte den med enten enkle eller doble anførselstegn. Vi kan derfor ikke sette samme tegn i strengen siden det da betyr slutt på strengen.
# I tilegg finnes det «usynlige» tegn som vi ikke får skrevet inn på vanlig måte.

# %% [markdown]
# #### Escape-tegn/escapesekvens

# %% [markdown]
# Løsningen er å bruke såkalte Escape-tegn eller escapesekvenser.
# Det vil si at vi setter en bakoverskråstrek \\ (og da har det også blitt et ulovlig tegn) etterfulgt av et annet tegn.
#
# Oversikt over escape-tegn:

# %% [markdown]
# ![Esc-tegn.png](attachment:c9c6b86e-a372-4c13-8164-8719121e4c83.png)

# %%
print('For å skrive ut \', \" og \\\nmå vi bruke \nescape-tegn')
# Out:
# For å skrive ut ', " og \
# må vi bruke
# escape-tegn
